# %%
'''
This homework defines one method, called "arithmetic".
that method, type `help homework2.arithmetic`.
'''

def arithmetic(x, y):
    """
    Modify this code so that it performs one of four possible functions, 
    as specified in the following table:

                        isinstance(x,str)  isinstance(x,float)
    isinstance(y,str)   return x+y         return str(x)+y
    isinstance(y,float) return x*int(y)    return x*y
    """
    if isinstance(y, str):
        if isinstance(x, str):
            return x + y
        elif isinstance(x, float):
            return str(x) + y
    elif isinstance(y, float):
        if isinstance(x, str):
            return x * int(y)
        elif isinstance(x, float):
            return x * y
    return 0

# %%
import importlib
import homework2
importlib.reload(homework2)

# Test a specific case (e.g., String + String)
print(homework2.arithmetic("foo", "bar"))
# Out:
# foobar

# %%
import grade
# Out:
# ....
# ----------------------------------------------------------------------
# Ran 4 tests in 0.008s
#
# OK
# 4 successes out of 4 tests run
# Score: 100%

# %%
import homework2
help(homework2)
# Out:
# Help on module homework2:
#
# NAME
#     homework2
#
# DESCRIPTION
#     This homework defines one method, called "arithmetic".
#     that method, type `help homework2.arithmetic`.
#
# FUNCTIONS
#     arithmetic(x, y)
#         Modify this code so that it performs one of four possible functions,
#         as specified in the following table:
#
#                             isinstance(x,str)  isinstance(x,float)
#         isinstance(y,str)   return x+y         return str(x)+y
#         isinstance(y,float) return x*int(y)    return x*y
#
# FILE
#     c:\users\user\documents\github\intro_speech_understanding\lec02\homework2.py

# %%
importlib.reload(grade)
# Out:
# ....
# ----------------------------------------------------------------------
# Ran 4 tests in 0.012s
#
# OK
# 4 successes out of 4 tests run
# Score: 100%
# <module 'grade' from 'C:\\Users\\user\\Documents\\GitHub\\intro_speech_understanding\\lec02\\grade.py'>
